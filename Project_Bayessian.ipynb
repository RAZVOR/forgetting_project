# %%
# %load_ext autoreload
# %autoreload 2

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from torch.optim.lr_scheduler import StepLR
from tqdm import tqdm_notebook as tqdm
import numpy as np
from scipy.special import softmax
from copy import copy
from matplotlib import pyplot as plt
import pandas as pd
from sklearn.metrics import r2_score
from scipy import stats
import scipy
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA

from utils import *
from dataloader import *
from torch.optim import SGD

params = {
    'lr': 0.1,
    'weight_decay': 5e-4,
    'batch_size': 512,
    'epoches': 30,
}

use_cuda = True
torch.manual_seed(42)

if use_cuda:
    
    device = torch.device("cuda")
else:
    device = torch.device("cpu")

train_kwargs = {'batch_size': params['batch_size']}
test_kwargs = {'batch_size': params['batch_size']}

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(1, 32, 3, 1)
        self.conv2 = nn.Conv2d(32, 64, 3, 1)
        self.fc1 = nn.Linear(9216, 128)
        self.fc2 = nn.Linear(128, 10)

    def get_latent(self, x):
        x = self.conv1(x)
        x = F.relu(x)
        x = self.conv2(x)
        x = F.relu(x)
        x = F.max_pool2d(x, 2)
        #x = self.dropout1(x)
        x = torch.flatten(x, 1)
        x = self.fc1(x)

        return x

    def get_out(self, latent):
        x = latent
        x = self.fc2(x)
        #output = F.log_softmax(x, dim=1)
        output = x

        return output
    
    def forward(self, x):
        x = self.get_latent(x)
        x = self.fc2(x)
        #output = F.log_softmax(x, dim=1)
        output = x
        return output

# %%
class LatentMetric:
  def __init__(self):
    self.res_epoches = []

  def add_epoch(self, latent):
    self.res_epoches.append(latent)

  def compute(self):
    pass

# %% [markdown]
# ## Latent space metrics
#
# **Variance2**: $ \sigma( \|M_i - E[M_i]\|_2 ) $
#
# **Mean abs shift**: $ E[  ] $

# %%
class VarianceMetric(LatentMetric):
  def __init__(self):
    super().__init__()

  def compute(self):
    stds = np.std(self.res_epoches, 0)
    stds = np.linalg.norm(stds, axis=-1)
    return stds

class VarianceMetric2(LatentMetric):
    def __init__(self):
        super().__init__()

    def compute(self):
        center = np.mean(self.res_epoches, 0)
        dist = [np.linalg.norm(e-center, axis=-1) for e in self.res_epoches]
        stds = np.std(dist, 0)
        print(stds.shape)

        return stds

class MeanAbsShiftMetric(LatentMetric):
  def __init__(self):
    super().__init__()

  def compute(self):
    a = self.res_epoches[1:]
    adiff = np.linalg.norm(np.array(a[1:])-np.array(a[:-1]), axis=-1)

    return adiff.mean(0)

class VarAbsShiftMetric(LatentMetric):
  def __init__(self):
    super().__init__()

  def compute(self):
    a = self.res_epoches[1:]
    adiff = np.linalg.norm(np.array(a[1:])-np.array(a[:-1]), axis=-1)

    return adiff.std(0)

class JustDistanceMetric(LatentMetric):
  def __init__(self):
    super().__init__()

  def compute(self):
    center = np.mean(self.res_epoches, 2)
    dist = [np.linalg.norm(e-center[i].reshape(-1,1), axis=-1) for i, e in enumerate(self.res_epoches)]
    res = np.mean(dist, 0)
    return res

class VelocityMetric(LatentMetric):
    def __init__(self):
        super().__init__()

    def compute(self):
        a = self.res_epoches
        adiff = np.linalg.norm(np.array(a[1:])-np.array(a[:-1]), axis=-1)
        speed = 1/adiff
        velocity = np.abs(speed[1:]-speed[:-1])
    
        res = velocity.mean(0)
        return res

# %%
class LabelMetric:
  def __init__(self):
    self.labels = None
    self.probs_epoches = []

  def add_epoch(self, probs_epoch):
    self.probs_epoches.append(probs_epoch)

  def add_labels(self, labels):
    self.labels = labels

  def compute(self):
    pass

class UncertantyMetric(LabelMetric):
    def __init__(self):
        super().__init__()
    
    def _unsertanty(self, probs, labels):
        lab_hot = labels.reshape(-1,1)
        #probs = np.exp(probs)
        return np.max(probs, axis=1)
    
    def compute(self):
        unserts = [self._unsertanty(p, self.labels) for p in self.probs_epoches]
        unsert_mean = 1.0 - np.mean( unserts, 0 )
        return unsert_mean

    def compute0(self):
        unserts = [self._unsertanty(self.probs_epoches[-1], self.labels)]
        unsert_mean = 1.0 - np.mean( unserts, 0 )
        return unsert_mean

class UEntropyMetric(LabelMetric):
    def __init__(self):
        super().__init__()
    
    def _entropy(self, probs, labels):
        log_probs = np.log(probs)
        return np.sum(probs*log_probs, axis=1)
    
    def compute(self):
        unserts = [self._entropy(p, self.labels) for p in [self.probs_epoches[-1]]]
        unsert_mean = -np.mean( unserts, 0 )
        return unsert_mean

class ConfidenceMetric(LabelMetric):
    def __init__(self):
        super().__init__()
    
    def _unsertanty(self, probs, labels):
        lab_hot = labels.reshape(-1,1).astype(int)
        #probs = np.exp(probs)
        return np.take_along_axis(probs, lab_hot, axis=1).reshape(-1) 

    def _entropy(self, log_probs, labels):
        probs = np.exp(log_probs)
        return np.sum(probs*log_probs, axis=1)

    def compute(self):
        unserts = [self._unsertanty(p, self.labels) for p in self.probs_epoches[:]]
        unsert_mean = np.mean(unserts, 0)
        return unsert_mean

class VariabilityMetric(LabelMetric):
    def __init__(self):
        super().__init__()
    
    def _unsertanty(self, probs, labels):
        lab_hot = labels.reshape(-1,1).astype(int)
        #probs = np.exp(probs)
        return np.take_along_axis(probs, lab_hot, axis=1).reshape(-1) 

    def _entropy(self, log_probs, labels):
        probs = np.exp(log_probs)
        return np.sum(probs*log_probs, axis=1)

    def compute(self):
        unserts = [self._unsertanty(p, self.labels) for p in self.probs_epoches[:]]
        unsert_mean = np.std(unserts, 0)
        return unsert_mean

# %%
def compute_correlation( ref_obj1, ref_obj2, class1, class2 ):
    
    m1 = copy.copy(ref_obj1)
    m1.__class__ = class1
    res1 = m1.compute()
    
    m2 = copy(ref_obj2)
    m2.__class__ = class2
    res2 = m2.compute()
    
    return np.corrcoef(res1, res2)[0,1]

def compute_r2( ref_obj1, ref_obj2, class1, class2 ):
    
    m1 = copy.copy(ref_obj1)
    m1.__class__ = class1
    res1 = m1.compute()
    
    m2 = copy(ref_obj2)
    m2.__class__ = class2
    res2 = m2.compute()

    res1 = (res1-res1.mean())/res1.std()
    res2 = (res2-res2.mean())/res2.std()
    
    #return r2_score(res1, res2)
    slope, intercept, r_value, p_value, std_err = scipy.stats.linregress(res1, res2)

    return r_value

def compute_spr( ref_obj1, ref_obj2, class1, class2 ):
    
    m1 = copy.copy(ref_obj1)
    m1.__class__ = class1
    res1 = m1.compute()
    
    m2 = copy.copy(ref_obj2)
    m2.__class__ = class2
    res2 = m2.compute()
    r = stats.spearmanr(res1, res2).statistic
    return r

def corr_with_arr(ref_obj1, class1, res2):
    m1 = copy.copy(ref_obj1)
    m1.__class__ = class1
    res1 = m1.compute()

    return np.corrcoef(res1, res2)[0,1]

def get_metr_values(ref_obj1, class1):
    m1 = copy.copy(ref_obj1)
    m1.__class__ = class1
    res1 = m1.compute()
    return res1

# %%
def get_highest(scores, k = 15):
    return np.argsort(scores)[-k:]

def get_lowest(scores, k = 15):
    return np.argsort(scores)[:k]

def plot_images(dataset: torch.utils.data.Dataset, indices: np.ndarray) -> None:
    fig = plt.figure(figsize=(len(indices)*3, 3))
    for i, idx in enumerate(indices):
        img = dataset.data[idx]
        if img.shape[0] == 3:
            img = img.transpose((1, 2, 0))
        ax = fig.add_subplot(1, len(indices), i+1)
        ax.axis('off')
        ax.imshow(img)

    plt.show()

def plot_lh( ds, scores, name ):
    hs = get_highest(scores)
    lw = get_lowest(scores)
    print(f'Highest score by {name}')
    plot_images(ds, hs)
    print(f'Lowest score by {name}')
    plot_images(ds, lw)

def plot_lh_obj( ds, ref_obj, cls, name ):
    m = copy(ref_obj)
    m.__class__ = cls
    res = m.compute()

    plot_lh(ds, res, name)

# %%
if use_cuda:
    cuda_kwargs = {'num_workers': 1,
                    'pin_memory': True,
                    'shuffle': False}
    train_kwargs.update(cuda_kwargs)
    test_kwargs.update(cuda_kwargs)
else:
    cpu_kwargs = {'shuffle': False}
    train_kwargs.update(cpu_kwargs)
    test_kwargs.update(cpu_kwargs)

# %% [markdown]
# ## Second split forgetting

# %%
model = Net().to(device)

loss_fn = torch.nn.CrossEntropyLoss(label_smoothing=0)

#The name of the first and second split datasets. Keep these same
dataset1 = "mnist"
dataset2 = "mnist"


#Training parameters for first and second split training
weight_decay = 5e-4
peak_lr_pre = 0.1
peak_lr_ft = 0.1
batch_size = 512

#Label Noise Ratio in first and second split
label_noise_ratio_pre = 0.0
label_noise_ratio_ft = 0.0

#Model type and learning schedule
model_type = "resnet9" 
schedule = "triangle" 
seed = 0

#Extra Parameters, not needed
minority_1 = 0
minority_2 = 0

all_args = {"dataset1":dataset1, "dataset2":dataset2, "wd":weight_decay, "lr1":peak_lr_pre, "lr2":peak_lr_ft, 
            "noise_1":label_noise_ratio_pre, "noise_2":label_noise_ratio_ft, "model":model_type, "schedule":schedule,
            "minority_1":minority_1, "minority_2":minority_2, "seed":seed, "batch_size":batch_size, "log_factor":0,"seed_superclass":0}

# %%
#Dictionary containing first and second split data loaders, noise mask and other data-dependent quantities
pre_dict, ft_dict = return_loaders(all_args)
print(pre_dict.keys())
preloader = pre_dict["train_loader"]
preloader_test = pre_dict["test_loader"]
ftloader = ft_dict["train_loader"]
# Out:
# dict_keys(['train_loader', 'test_loader', 'noise_mask', 'rare_mask', 'train_dataset'])

# %%
#Stage 1 Training
optimizer = SGD(model.parameters(), lr=0.1, momentum=0.9, weight_decay=5e-4)
scheduler, EPOCHS = get_scheduler_epochs(all_args["schedule"], optimizer, preloader)

ret_pre = train_ssf(model, preloader, optimizer, scheduler, loss_fn, EPOCHS = EPOCHS, eval_every = True, eval_loader= preloader, test_loader = preloader_test)

torch.save(model.state_dict(), f"models/{all_args['dataset1']}/stage_1.pt")


#Stage 2 Training
optimizer = SGD(model.parameters(), lr=0.1, momentum=0.9, weight_decay=5e-4)
scheduler, EPOCHS = get_scheduler_epochs(all_args["schedule"], optimizer, ftloader)


ret_ft = train_ssf(model, ftloader, optimizer, scheduler, loss_fn, EPOCHS = EPOCHS, eval_every = True, eval_loader= preloader)

torch.save(model.state_dict(), f"models/{all_args['dataset1']}/stage_2.pt")
# Out:
# Epoch: 1 | Eval Loader Accuracy: 85.2833%
# Epoch: 2 | Eval Loader Accuracy: 90.2000%
# Epoch: 3 | Eval Loader Accuracy: 91.4967%
# Epoch: 4 | Eval Loader Accuracy: 94.1367%
# Epoch: 5 | Eval Loader Accuracy: 96.6667%
# Epoch: 5 | Accuracy: 95.4067% | Loss: 3.04e-04
# Epoch: 6 | Eval Loader Accuracy: 97.7633%
# Epoch: 7 | Eval Loader Accuracy: 98.2100%
# Epoch: 8 | Eval Loader Accuracy: 98.1033%
# Epoch: 9 | Eval Loader Accuracy: 98.8567%
# Epoch: 10 | Eval Loader Accuracy: 98.0833%
# Epoch: 10 | Accuracy: 98.6300% | Loss: 8.64e-05
# Epoch: 11 | Eval Loader Accuracy: 99.2300%
# Epoch: 12 | Eval Loader Accuracy: 99.0900%
# Epoch: 13 | Eval Loader Accuracy: 99.3433%
# Epoch: 14 | Eval Loader Accuracy: 99.1933%
# Epoch: 15 | Eval Loader Accuracy: 99.6700%
# Epoch: 15 | Accuracy: 99.4033% | Loss: 3.75e-05
# Epoch: 16 | Eval Loader Accuracy: 99.3067%
# Epoch: 17 | Eval Loader Accuracy: 99.6667%
# Epoch: 18 | Eval Loader Accuracy: 99.8533%
# Epoch: 19 | Eval Loader Accuracy: 99.7033%
# Epoch: 20 | Eval Loader Accuracy: 99.8467%
# Epoch: 20 | Accuracy: 99.7467% | Loss: 1.89e-05
# Epoch: 21 | Eval Loader Accuracy: 99.9100%
# Epoch: 22 | Eval Loader Accuracy: 99.9200%
# Epoch: 23 | Eval Loader Accuracy: 99.9400%
# Epoch: 24 | Eval Loader Accuracy: 99.9467%
# Epoch: 25 | Eval Loader Accuracy: 99.9600%
# Epoch: 25 | Accuracy: 99.9367% | Loss: 9.34e-06
# Epoch: 26 | Eval Loader Accuracy: 99.9833%
# Epoch: 27 | Eval Loader Accuracy: 99.9767%
# Epoch: 28 | Eval Loader Accuracy: 99.9267%
# Epoch: 29 | Eval Loader Accuracy: 99.9867%
# Epoch: 30 | Eval Loader Accuracy: 99.9700%
# Epoch: 30 | Accuracy: 99.9800% | Loss: 6.46e-06
# Epoch: 31 | Eval Loader Accuracy: 99.9867%
# Epoch: 32 | Eval Loader Accuracy: 99.9900%
# Epoch: 33 | Eval Loader Accuracy: 99.9900%
# Epoch: 34 | Eval Loader Accuracy: 100.0000%
# Epoch: 35 | Eval Loader Accuracy: 99.9900%
# Epoch: 35 | Accuracy: 99.9967% | Loss: 5.47e-06
# Epoch: 36 | Eval Loader Accuracy: 99.9833%
# Epoch: 37 | Eval Loader Accuracy: 99.9833%
# Epoch: 38 | Eval Loader Accuracy: 99.9900%
# Epoch: 39 | Eval Loader Accuracy: 99.9733%
# Epoch: 40 | Eval Loader Accuracy: 100.0000%
# Epoch: 40 | Accuracy: 99.9833% | Loss: 6.93e-06
# Epoch: 41 | Eval Loader Accuracy: 99.9900%
# Epoch: 42 | Eval Loader Accuracy: 100.0000%
# Epoch: 43 | Eval Loader Accuracy: 100.0000%
# Epoch: 44 | Eval Loader Accuracy: 99.9933%
# Epoch: 45 | Eval Loader Accuracy: 100.0000%
# Epoch: 45 | Accuracy: 99.9867% | Loss: 5.78e-06
# Epoch: 46 | Eval Loader Accuracy: 100.0000%
# Epoch: 47 | Eval Loader Accuracy: 100.0000%
# Epoch: 48 | Eval Loader Accuracy: 100.0000%
# Epoch: 49 | Eval Loader Accuracy: 100.0000%
# Epoch: 50 | Eval Loader Accuracy: 100.0000%
# Epoch: 50 | Accuracy: 99.9900% | Loss: 5.11e-06
# Epoch: 51 | Eval Loader Accuracy: 99.9900%
# Epoch: 52 | Eval Loader Accuracy: 99.9933%
# Epoch: 53 | Eval Loader Accuracy: 100.0000%
# Epoch: 54 | Eval Loader Accuracy: 100.0000%
# Epoch: 55 | Eval Loader Accuracy: 100.0000%
# Epoch: 55 | Accuracy: 99.9933% | Loss: 5.40e-06
# Epoch: 56 | Eval Loader Accuracy: 100.0000%
# Epoch: 57 | Eval Loader Accuracy: 100.0000%
# Epoch: 58 | Eval Loader Accuracy: 99.9933%
# Epoch: 59 | Eval Loader Accuracy: 100.0000%
# Epoch: 60 | Eval Loader Accuracy: 100.0000%
# Epoch: 60 | Accuracy: 100.0000% | Loss: 5.32e-06
# Epoch: 1 | Eval Loader Accuracy: 99.9700%
# Epoch: 2 | Eval Loader Accuracy: 99.8133%
# Epoch: 3 | Eval Loader Accuracy: 99.7167%
# Epoch: 4 | Eval Loader Accuracy: 99.2367%
# Epoch: 5 | Eval Loader Accuracy: 99.0400%
# Epoch: 5 | Accuracy: 98.7933% | Loss: 7.19e-05
# Epoch: 6 | Eval Loader Accuracy: 99.3600%
# Epoch: 7 | Eval Loader Accuracy: 99.2833%
# Epoch: 8 | Eval Loader Accuracy: 98.9600%
# Epoch: 9 | Eval Loader Accuracy: 99.0200%
# Epoch: 10 | Eval Loader Accuracy: 98.8167%
# Epoch: 10 | Accuracy: 99.1267% | Loss: 5.16e-05
# Epoch: 11 | Eval Loader Accuracy: 98.7967%
# Epoch: 12 | Eval Loader Accuracy: 98.9367%
# Epoch: 13 | Eval Loader Accuracy: 98.8800%
# Epoch: 14 | Eval Loader Accuracy: 98.8500%
# Epoch: 15 | Eval Loader Accuracy: 98.8867%
# Epoch: 15 | Accuracy: 99.6467% | Loss: 2.26e-05
# Epoch: 16 | Eval Loader Accuracy: 98.7833%
# Epoch: 17 | Eval Loader Accuracy: 98.9467%
# Epoch: 18 | Eval Loader Accuracy: 98.9600%
# Epoch: 19 | Eval Loader Accuracy: 98.9133%
# Epoch: 20 | Eval Loader Accuracy: 98.9600%
# Epoch: 20 | Accuracy: 99.9100% | Loss: 9.64e-06
# Epoch: 21 | Eval Loader Accuracy: 98.9633%
# Epoch: 22 | Eval Loader Accuracy: 98.9533%
# Epoch: 23 | Eval Loader Accuracy: 98.9233%
# Epoch: 24 | Eval Loader Accuracy: 99.0133%
# Epoch: 25 | Eval Loader Accuracy: 98.9800%
# Epoch: 25 | Accuracy: 99.9867% | Loss: 5.96e-06
# Epoch: 26 | Eval Loader Accuracy: 98.9433%
# Epoch: 27 | Eval Loader Accuracy: 98.9967%
# Epoch: 28 | Eval Loader Accuracy: 98.9267%
# Epoch: 29 | Eval Loader Accuracy: 98.8900%
# Epoch: 30 | Eval Loader Accuracy: 98.9867%
# Epoch: 30 | Accuracy: 99.9900% | Loss: 6.39e-06
# Epoch: 31 | Eval Loader Accuracy: 98.9100%
# Epoch: 32 | Eval Loader Accuracy: 98.9867%
# Epoch: 33 | Eval Loader Accuracy: 98.9367%
# Epoch: 34 | Eval Loader Accuracy: 98.9167%
# Epoch: 35 | Eval Loader Accuracy: 98.9400%
# Epoch: 35 | Accuracy: 99.9933% | Loss: 5.87e-06
# Epoch: 36 | Eval Loader Accuracy: 98.8200%
# Epoch: 37 | Eval Loader Accuracy: 98.8167%
# Epoch: 38 | Eval Loader Accuracy: 98.8500%
# Epoch: 39 | Eval Loader Accuracy: 98.7233%
# Epoch: 40 | Eval Loader Accuracy: 98.8767%
# Epoch: 40 | Accuracy: 99.9900% | Loss: 6.88e-06
# Epoch: 41 | Eval Loader Accuracy: 98.8800%
# Epoch: 42 | Eval Loader Accuracy: 98.8467%
# Epoch: 43 | Eval Loader Accuracy: 98.9033%
# Epoch: 44 | Eval Loader Accuracy: 98.8667%
# Epoch: 45 | Eval Loader Accuracy: 98.8700%
# Epoch: 45 | Accuracy: 100.0000% | Loss: 4.97e-06
# Epoch: 46 | Eval Loader Accuracy: 98.8967%
# Epoch: 47 | Eval Loader Accuracy: 98.8500%
# Epoch: 48 | Eval Loader Accuracy: 98.8733%
# Epoch: 49 | Eval Loader Accuracy: 98.8600%
# Epoch: 50 | Eval Loader Accuracy: 98.8733%
# Epoch: 50 | Accuracy: 100.0000% | Loss: 5.21e-06

# %%
masks_pre = ret_pre["acc_mask"]
masks_ft = ret_ft["acc_mask"]
noise_mask = pre_dict["noise_mask"]

learn_epochs = get_first_epoch_where_we_learn_forever(masks_pre)
forget_epochs = get_first_epoch_where_we_forget_forever(masks_ft)
learn = learn_epochs + np.random.uniform(-0.5, 0.5, size = learn_epochs.shape)
forget = forget_epochs 
fg = forget_epochs.max()
forget[forget_epochs!=fg] = forget[forget_epochs!=fg] + np.random.uniform(-0.4, 0.4, size = forget_epochs[forget_epochs!=fg].shape)
plt.xlabel("Learning Time")
plt.ylabel("Second Split Forgetting Time")

plt.axhline(y=fg-0.5, color='r', linestyle='--')
plt.scatter(learn, forget, s= 1.5, c = "b")

# %%
import matplotlib.gridspec as gridspec

x, y  = learn, forget
fig = plt.figure(figsize=(8,8))
gs = gridspec.GridSpec(5, 5)
ax_main = plt.subplot(gs[1:, :4])
ax_xDist = plt.subplot(gs[0, :4])#,sharex=ax_main)
ax_yDist = plt.subplot(gs[1:, 4])#,sharey=ax_main)

ax_main.scatter(x,y,marker='.',c='tab:blue',s=50)
ax_main.set(xlabel="Learning Time", ylabel="Second Split Forgetting Time")
ax_main.axhline(y=fg-0.5, color='tab:red', linestyle='--', c = 'tab:red')
ax_xDist.hist(x,bins=61,color='tab:red',align='mid')
ax_xDist.set(ylabel='#Examples')

ax_yDist.hist(y,bins=61,color='tab:red', orientation='horizontal',align='mid')
ax_yDist.set(xlabel='#Examples')

ax_xDist.set_yscale('log')
ax_yDist.set_xscale('log')
ax_yDist.set_yticklabels([])
ax_xDist.set_xticklabels([])


#plt.savefig("plots/mnist_vis.svg")
plt.show()

# %%
import pickle
with open('mnist_final.pickle', 'wb') as handle:
    pickle.dump([learn, forget], handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
latentMetric = LatentMetric()
latentMetric.res_epoches = ret_pre['latent_emb']
labelMetric = LabelMetric()
labelMetric.probs_epoches = [a.numpy() for a in ret_pre['probs']]
labelMetric.labels = ftloader.dataset.targets.cpu().numpy()

# %% [markdown]
# ## PCA and TSNA analysis

# %%
complex_flag = (learn > 30) & (forget > 40)
complex_idx = np.where( complex_flag )[0][:50]
mis_flag = (learn > 30) & (forget < 20)
mis_idx = np.where( mis_flag )[0][:10]
easy_idx = np.where( ~complex_flag & ~mis_flag )[0][:100]

# %%
pca = PCA(n_components = 2)
pca.fit( latentMetric.res_epoches[0] )
# Out:
# PCA(n_components=2)

# %%
fig, axs = plt.subplots(6, 5, figsize=(20, 15), sharex=True, sharey=True)

for i, ax in enumerate(axs.flat):
    #ax.set(xlabel='x-label', ylabel='y-label')

    latent_space_pca = pca.transform( latentMetric.res_epoches[i] )
    
    ax.scatter(
        latent_space_pca[easy_idx,0],
        latent_space_pca[easy_idx,1],
        color="turquoise",
        label="easy"
    )
    ax.scatter(
        latent_space_pca[complex_idx,0],
        latent_space_pca[complex_idx,1],
        color="darkorange",
        label="complex"
    )
    ax.scatter(
        latent_space_pca[mis_idx,0],
        latent_space_pca[mis_idx,1],
        color="green",
        label="mis"
    )

# Hide x labels and tick labels for top plots and y ticks for right plots.
for ax in axs.flat:
    ax.label_outer()

# %% [markdown]
# ## Correlation with SSF metric

# %%
complex_flag = (learn > 30) & (forget > 45)
mislabel_flag = (learn > 30) & (forget < 10)

complex_metr = learn * forget

# %%
named_metrics = {
    'Mean abs shift': MeanAbsShiftMetric,
    'Var abs shift': VarianceMetric2,
    'Velocity': VelocityMetric,
    'Distance': JustDistanceMetric
}

# %%
# Correlation with SSF
pd.DataFrame({
    'name': list(named_metrics.keys()),
    'correlation with SSF': [
        corr_with_arr( latentMetric, C, complex_metr )
        for C in named_metrics.values()
    ],
})
# Out:
# (30000,)
#              name  correlation with SSF
# 0  Mean abs shift              0.013884
# 1   Var abs shift             -0.051491
# 2        Velocity             -0.019729
# 3        Distance             -0.117187

# %%
m1, m2 = get_metr_values( latentMetric, JustDistanceMetric ), get_metr_values( latentMetric, VelocityMetric )

plt.scatter(
    m1[ ~complex_flag ][:300],
    m2[ ~complex_flag ][:300],
    label='easy'
)
plt.scatter(
    m1[ complex_flag ][:200],
    m2[ complex_flag ][:200],
    label='Complex'
)
plt.scatter(
    m1[ mislabel_flag ][:200],
    m2[ mislabel_flag ][:200],
    label='mislabel'
)
plt.xlabel('Distance')
plt.ylabel('Velocity')
plt.legend()

# %% [markdown]
# Metrics do not really correlate but at least we can separate region with hard samples according to our metrics

# %% [markdown]
# ## Correlation with uncertanty

# %%
# Correlation with uncalebrated uncertanty

pd.DataFrame({
    'name': list(named_metrics.keys()),
    'correlation with Uncertainty(max prob)': [
        compute_spr( labelMetric, latentMetric, UncertantyMetric, C )
        for C in named_metrics.values()
    ],
    'correlation with Uncertainty(entropy)': [
        compute_spr( labelMetric, latentMetric, UEntropyMetric, C )
        for C in named_metrics.values()
    ]
})
# Out:
#              name  correlation with Uncertainty(max prob)  \
# 0  Mean abs shift                               -0.123631
# 1   Var abs shift                               -0.153452
# 2        Velocity                                0.048584
# 3        Distance                               -0.298133
#
#    correlation with Uncertainty(entropy)
# 0                              -0.291200
# 1                              -0.278445
# 2                               0.177196
# 3                              -0.555905

# %% [markdown]
# ### Correlation with variabilty and confidence
# peper:

# %%
pd.DataFrame({
    'name': list(named_metrics.keys()),
    'correlation with Confidence': [
        compute_spr( labelMetric, latentMetric, ConfidenceMetric, C )
        for C in named_metrics.values()
    ],
    'correlation with Variability': [
        compute_spr( labelMetric, latentMetric, VariabilityMetric, C )
        for C in named_metrics.values()
    ]
})
# Out:
#              name  correlation with Confidence  correlation with Variability
# 0  Mean abs shift                    -0.373329                     -0.334204
# 1   Var abs shift                    -0.380458                     -0.342136
# 2        Velocity                     0.336143                      0.310206
# 3        Distance                    -0.431024                     -0.380221

# %%
m1, m2 = get_metr_values( labelMetric, VariabilityMetric ), get_metr_values( labelMetric, ConfidenceMetric )

plt.scatter(
    m1[ ~complex_flag ][:],
    m2[ ~complex_flag ][:],
    label='easy'
)
plt.scatter(
    m1[ complex_flag ][:200],
    m2[ complex_flag ][:200],
    label='hard'
)
plt.scatter(
    m1[ mislabel_flag ][:200],
    m2[ mislabel_flag ][:200],
    label='mislabel'
)
plt.xlabel('Confidence')
plt.ylabel('Var uncertanty')
plt.legend()

# %%
m1, m2 = get_metr_values( latentMetric, JustDistanceMetric ), get_metr_values( latentMetric, VelocityMetric )

plt.scatter(
    m1[ ~complex_flag ][:500],
    m2[ ~complex_flag ][:500],
    label='easy'
)
plt.scatter(
    m1[ complex_flag ][:200],
    m2[ complex_flag ][:200],
    label='hard'
)
plt.scatter(
    m1[ mislabel_flag ][:200],
    m2[ mislabel_flag ][:200],
    label='mislabel'
)
plt.xlabel('Distance')
plt.ylabel('Veclocity')
plt.legend()

# %% [markdown]
# ## Visualization uncertant and confident expamples

# %%
plot_lh_obj( dataset1_0, latentMetric, VelocityMetric, name = 'Velocity' )
# Out:
# (60000,)
# Highest score by Velocity
# Lowest score by Velocity

# %%
plot_lh_obj( dataset1_0, latentMetric, VarianceMetric2, name = 'Variance(alt)' )
# Out:
# Highest score by Variance(alt)
# Lowest score by Variance(alt)

# %%
plot_lh_obj( dataset1_0, labelMetric, UEntropyMetric, name = 'Entropy' )
# Out:
# Highest score by Entropy
# Lowest score by Entropy

# %% [markdown]
# ## Unlabelled dataset metrics

# %%
latentMetricTest = LatentMetric()
latentMetricTest.res_epoches = [r.float().cpu().numpy() for r in ret_pre["latent_emb_test"]]

# %%
m1_test, m2_test = get_metr_values( latentMetricTest, JustDistanceMetric ), get_metr_values( latentMetricTest, VelocityMetric )

# %%
idx = (forget_epochs>50) & (learn_epochs>30)
imshow(pre_dict["train_dataset"].data[idx][:10])
print(pre_dict["train_dataset"].targets[idx][:10])
# Out:
# tensor([4, 1, 9, 1, 7, 7, 7, 9, 1, 9])

# %%
idx1 = (m1_test < 12) & (m2_test < 0.2)
imshow(pre_dict["test_loader"].dataset.data[idx1][:10])
print(pre_dict["test_loader"].dataset.targets[idx1][:10])
# Out:
# tensor([1, 1, 9, 1, 1, 1, 4, 5, 1, 3])
